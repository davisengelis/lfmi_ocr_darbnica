# %%
import pytesseract
from PIL import Image
import cv2
from matplotlib import pyplot as plt

# %%
failu_nosaukumi = '/Users/davisengelis/Purvs_un_Sudis.pdf/pytest/purva_teksti_failu_nosaukumi.txt'
text = pytesseract.image_to_string(failu_nosaukumi, lang='lav')

print(text)
# Out:
# Pa dziesmotā avangarda pēdām
#
# Nenoniecinot nevienu no mūsu sabiedrisko un kulturālo aktivitāšu
# izpausmes veidiem, mums tomēr jāatzīst vecā un daudzkārt pierādīt
# patiesība, ka visos laikos mūsu siržu vērējas pretim nacionālai pašapziņai
# un vienībai ir bijušas dziesmas. Un vai mūsu koyi arī nav tie, kas mūs spējuši
# pulcināt vienkopus vislielākā skaitā? Dziesmu dienas, to atskaņas un citi
# koru kopkoncerti visspilgtāk likuši izjust, ka esam locekļi vienā kopējā saimē,
# kautarī daudziem pēdējie skati dzimtam krastam pabāluši, kaut bieži lietas
# izvērtējam tikai no personīgās materiālās perspektīvas, kultūru — par cik
# tā dos atlikumu. Bieži vien eksperimentējam arī ar dažādu principu
# skaldīšanu. Bet koyi ir mūs aicinājuši sasaukties kā Anglijā, tā Savienotajās
# Valstīs, Kanādā un Austrālijā. Aizņemoties šajā kontinentā iecienīto
# reklāmas frāzi, varētu teikt, ka līdz Kanādas latviešu dziesmu svētkiem
# ...
